# %% [markdown]
# # How Open Is the Rijksmuseum? A Historical Perspective on Its Web-Archived Presence

# %% [markdown]
#  ### Nadezhda  Povroznik [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/0000-0003-2044-8147)
# Technical University of Darmstadt

# %% [markdown]
# [![cc-by](https://licensebuttons.net/l/by/4.0/88x31.png)](https://creativecommons.org/licenses/by/4.0/)
# ©<AUTHOR or ORGANIZATION / FUNDER>. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY](https://creativecommons.org/licenses/by/4.0/)

# %%
from IPython.display import Image, display

display(Image("./media/folders.JPG"))

# %% [markdown]
# web history, web archives, Internet Archive, National Library of the Netherlands, Rijksmuseum, openness, source criticism, historical record of web presence, URL analysis, data visualisations

# %% [markdown]
# This is an abstract (...)

# %% [markdown]
# ## Introduction

# %% [markdown]
# The Rijksmuseum in Amsterdam has been widely recognised as a pioneering institution in making cultural heritage openly accessible to researchers and the wider public (Terras, 2015). The digital transformation of the Dutch museums can be traced back to 1969 when the government significantly subsidised the museum sector, favouring the first wave of digitisation (Navarrete, 2014). Throughout the decades, the Rijksmuseum has not only integrated museum data into its computer system but also made more than 823,077 artworks, 348,151 library items, and 196,648 visitor stories publicly available online (Rijksmuseum, 2025). The milestones of openness can be allocated on the timeline, mapping the release of a substantial portions of its resources into the public domain under a Creative Commons Zero (CC0) license since 2011; the publication of its digital collections as Linked Open Data (Dijkshoorn et al., 2018); the promotion of use and reuse of its digital collections in high resolution through initiatives such as the Rijksawards and the Rijksstudio (Volkers, 2017); and the development of tools for data search and exploration (Mensink & van Gemert, 2014), alongside other projects. In fact, having these noticeable milestones described and accounted for, the historical perspective of the development of the museum’s digital transformation in openness remains understudied, leaving significant gaps in understanding how it emerged, was implemented, and developed within this cultural heritage institution.

# %% [markdown]
# Do we have sufficient source base to analyse the shift in openness or understand the priorities in digital publishing of information on the web by the museum? Can we apply data-driven methodologies and inspect the data uploaded on the website over the past years? The opportunities to answer these questions depend mostly on the materials that were preserved by the web archives. To trace historical developments and investigate the museum’s web presence, analysing web-archived materials is essential. Web archives preserve unique snapshots of the museum’s online presence, serving as a historical record, invaluable for such study (Brügger, 2017). These repositories, particularly the Internet Archive and the Royal Library of the Netherlands (the Koninklijke Bibliotheek, KB), which is responsible for preserving the Dutch web, crawl websites to archive them for the future. At the same time, the web archives present unique challenges for historians: they are partial, sometimes inconsistent, and shaped by crawler technologies, and largely affected by the selection policies that determine what survives for future analysis and what remains omitted (REFS). As a fundamental practice in historical research, source criticism is a necessary step for evaluating this source base and, to determine what kinds of research questions we, as researchers, can raise, the questions of accuracy and completeness of web archive data must be addressed (Weber, 2018; REFS).

# %% [markdown]
# ## Related Work

# %% [markdown]
# Overview of the literature on the topic of Openness and Rijksmuseum: What do we know and what can we reconstruct from a historical perspective?
#
# 1) Digital transformation in the museums & Openness of Rijksmuseum - who studied, what kind of sources were used, what kind of outcomes were obtained? To what extent were the materials from the web archives utilised? Why is this research unique?
#
# 2) Web history and web archives - Scholarship on using the Internet Archive and national web archives for historical research (Brügger, Weber) - why these works are useful for my research? Discussions of methodological challenges: partiality, selection policies, crawler technologies.
#
# 3) How digital historians integrate source criticism into analysis of web archives.
#
# 4) Use of URL analysis, metadata comparison, data visualisations in previous studies.
#
# 5) Gaps in existing frameworks 1) methodologically 2) lack of detailed coverage studies for the Rijksmuseum.

# %% [markdown]
# ## Research Objectives

# %% [markdown]
# The first preserved snapshot of the Rijksmuseum’s website in the Internet Archive dates to 28 November 1999, marking the beginning of its preservation there, while the Dutch web archive (KB) started capturing the site in 2010; accordingly, this study focuses on the period from 1999 to June 2025, when the data were collected and analysed. By applying source criticism to these digital repositories, this study systematically observes datasets that document the Rijksmuseum’s web presence in historical depth, revealing both the possibilities and limitations of using materials from the Internet Archive and the KB as historical sources. It analyses these web-archived collections to determine the coverage of preserved materials over time, identify missing information, evaluate gaps, and assess overlaps that could support building a more comprehensive combined dataset. The study also examines how effectively these two major web archiving initiatives have captured the Rijksmuseum’s online presence and identifies temporal blind spots within the archival records.

# %% [markdown]
# This paper contributes to the methodology of web history by proposing frameworks for evaluating the reliability and completeness of web archives as historical sources. Its findings benefit researchers studying the web presence of the Rijksmuseum or other institutions and help develop best practices for using web-archived resources in historical analysis. For the museum, the study offers structured documentation of its institutional web records over time, supporting strategic reflection on future steps in preserving its web heritage. For web archives, particularly the KB, the analysis provides insights into coverage patterns and preservation challenges that can guide future collection development.

# %% [markdown]
# The narrative layer of the paper presents the analysis of the Rijksmuseum's web presence through web archive preservation in both the Internet Archive and the web collections of the KB. It will be addressed how well web archives preserve the museum’s website over time, and what this tells us about the investigation of the museum’s openness.

# %% [markdown]
# The data layer consists of statistical tables, data visualisations, and the code used in the analysis. The raw data from the Dutch web archive can not be published in open access due to copyright restrictions. The methodology employs URL analysis and metadata comparison to systematically evaluate the preservation process and assess the datasets.

# %% [markdown]
# The hermeneutic layer document and critically reflect on the research process. The source criticism methodology is in use to evaluate and compare the datasets. The analysis focuses on identifying coverage gaps, evaluating overlapping information between archives, and assessing the potential for building more comprehensive datasets by combining both repositories.

# %% [markdown]
# ## Methodology

# %% [markdown]
# URL Analysis
#
#
# find the file with structure of actions of what I was doing with what order
#
# What was specific for both web archives and what was specific for each separately. Did I used different methodologies to obtain data? Internet Archive - direct request to API, KB - data extraction at the KB Data Lab - via SolrWayback instance.
#
# Common practices in cleaning the data, removing symbols.
#
# how was solved the task on Unique URLs

# %% [markdown]
# ## Rijksmuseum's website preserved by the Internet archive

# %% [markdown]
# This paper contributes to the methodology of web history by proposing frameworks for evaluating the reliability and completeness of web archives as historical sources. Its findings benefit researchers studying the web presence of the Rijksmuseum or other institutions and help develop best practices for using web-archived resources in historical analysis. For the museum, the study offers structured documentation of its institutional web records over time, supporting strategic reflection on future steps in preserving its web heritage. For web archives, particularly the KB, the analysis provides insights into coverage patterns and preservation challenges that can guide future collection development.

# %% [markdown]
# ### Internet archive

# %% [markdown]
# This paper contributes to the methodology of web history by proposing frameworks for evaluating the reliability and completeness of web archives as historical sources. Its findings benefit researchers studying the web presence of the Rijksmuseum or other institutions and help develop best practices for using web-archived resources in historical analysis. For the museum, the study offers structured documentation of its institutional web records over time, supporting strategic reflection on future steps in preserving its web heritage. For web archives, particularly the KB, the analysis provides insights into coverage patterns and preservation challenges that can guide future collection development.

# %% [markdown]
# ### National Library of the Netherlands (KB)

# %% [markdown]
# This paper contributes to the methodology of web history by proposing frameworks for evaluating the reliability and completeness of web archives as historical sources. Its findings benefit researchers studying the web presence of the Rijksmuseum or other institutions and help develop best practices for using web-archived resources in historical analysis. For the museum, the study offers structured documentation of its institutional web records over time, supporting strategic reflection on future steps in preserving its web heritage. For web archives, particularly the KB, the analysis provides insights into coverage patterns and preservation challenges that can guide future collection development.

# %% [markdown]
# ### Comparing Datasets

# %% [markdown]
# This paper contributes to the methodology of web history by proposing frameworks for evaluating the reliability and completeness of web archives as historical sources. Its findings benefit researchers studying the web presence of the Rijksmuseum or other institutions and help develop best practices for using web-archived resources in historical analysis. For the museum, the study offers structured documentation of its institutional web records over time, supporting strategic reflection on future steps in preserving its web heritage. For web archives, particularly the KB, the analysis provides insights into coverage patterns and preservation challenges that can guide future collection development.

# %% [markdown]
# ## Discussion

# %% [markdown]
# This paper contributes to the methodology of web history by proposing frameworks for evaluating the reliability and completeness of web archives as historical sources. Its findings benefit researchers studying the web presence of the Rijksmuseum or other institutions and help develop best practices for using web-archived resources in historical analysis. For the museum, the study offers structured documentation of its institutional web records over time, supporting strategic reflection on future steps in preserving its web heritage. For web archives, particularly the KB, the analysis provides insights into coverage patterns and preservation challenges that can guide future collection development.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This paper contributes to the methodology of web history by proposing frameworks for evaluating the reliability and completeness of web archives as historical sources. Its findings benefit researchers studying the web presence of the Rijksmuseum or other institutions and help develop best practices for using web-archived resources in historical analysis. For the museum, the study offers structured documentation of its institutional web records over time, supporting strategic reflection on future steps in preserving its web heritage. For web archives, particularly the KB, the analysis provides insights into coverage patterns and preservation challenges that can guide future collection development.

# %% [markdown]
# This is a hermeneutic paragraph

# %% [markdown]
# Editor|1641|1798|1916
# ---|---|---|---
# Senan|0.55|0.4|0.3
# Henry|0.71|0.5|0.63

# %%
# Check your Python version
from platform import python_version
python_version()

#!python -V

# %%
# pandas package needs to be added to the requirements.txt 's file 
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/college.csv")
df
# Out:
#                                              Name PredominantDegree  \
# 0                        Alabama A & M University        Bachelor's
# 1             University of Alabama at Birmingham        Bachelor's
# 2             University of Alabama in Huntsville        Bachelor's
# 3                        Alabama State University        Bachelor's
# 4                       The University of Alabama        Bachelor's
# ...                                           ...               ...
# 1289        University of Connecticut-Avery Point        Bachelor's
# 1290           University of Connecticut-Stamford        Bachelor's
# 1291  California State University-Channel Islands        Bachelor's
# 1292              DigiPen Institute of Technology        Bachelor's
# 1293                           Neumont University        Bachelor's
#
#      HighestDegree        FundingModel           Region        Geography  \
# 0         Graduate              Public        Southeast    Mid-size City
# 1         Graduate              Public        Southeast    Mid-size City
# 2         Graduate              Public        Southeast    Mid-size City
# 3         Graduate              Public        Southeast    Mid-size City
# 4         Graduate              Public        Southeast       Small City
# ...            ...                 ...              ...              ...
# 1289      Graduate              Public      New England  Mid-size Suburb
# 1290      Graduate              Public      New England    Mid-size City
# 1291      Graduate              Public         Far West  Mid-size Suburb
# 1292      Graduate  Private For-Profit         Far West       Small City
# 1293    Bachelor's  Private For-Profit  Rocky Mountains    Mid-size City
#
#       AdmissionRate  ACTMedian  SATAverage  AverageCost  Expenditure  \
# 0            0.8989         17         823        18888         7459
# 1            0.8673         25        1146        19990        17208
# 2            0.8062         26        1180        20306         9352
# 3            0.5125         17         830        17400         7393
# 4            0.5655         26        1171        26717         9817
# ...             ...        ...         ...          ...          ...
# 1289         0.5940         24        1020        12946        11730
# 1290         0.4107         21        1017        13028         4958
# 1291         0.6443         20         954        22570        12026
# 1292         0.6635         28        1225        37848         5998
# 1293         0.7997         25        1104        37379         3298
#
#       AverageFacultySalary  MedianDebt  AverageAgeofEntry  MedianFamilyIncome  \
# 0                     7079     19500.0          20.629999             29039.0
# 1                    10170     16250.0          22.670000             34909.0
# 2                     9341     16500.0          23.190001             39766.0
# 3                     6557     15854.5          20.889999             24029.5
# 4                     9605     17750.0          20.770000             58976.0
# ...                    ...         ...                ...                 ...
# 1289                 14803     18983.0          20.120001             86510.0
# 1290                 14803     18983.0          20.120001             86510.0
# 1291                  8434     12500.0          24.850000             32103.0
# 1292                  7659     19000.0          21.209999             68233.0
# 1293                  6991     22313.0          24.750000             39241.0
#
#       MedianEarnings
# 0              27000
# 1              37200
# 2              41500
# 3              22400
# 4              39200
# ...              ...
# 1289           49700
# 1290           49700
# 1291           35800
# 1292           72800
# 1293           37300
#
# [1294 rows x 16 columns]
